# %% [markdown]
# **Google Drive Bağlantısı**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Dosyaları Zipten Çıkarma**

# %%
# !cd /content
# !unzip /content/drive/MyDrive/data_f1.zip

# %% [markdown]
# **Kurulumlar**

# %%
# !pip install ultralytics
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd /content/ultralytics

# %%
# !yolo mode=checks
from ultralytics import YOLO
from IPython.display import display, Image
# %cd /content/ultralytics

# %% [markdown]
# **Eğitim**

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=custom.yaml epochs=25 imgsz=640 batch=2 optimizer=SGD lr0=0.01 device=0
# Out:
# Ultralytics YOLOv8.0.5 🚀 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %% [markdown]
# **TensorBoard**

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/ultralytics/runs/detect/train

# %% [markdown]
# **Test (Eval)**

# %%
# !yolo task=detect mode=val model=/content/ultralytics/runs/detect/train/weights/last.pt data=custom.yaml

# %%
from IPython.display import display, Image
Image(filename=f'/content/ultralytics/runs/detect/train/confusion_matrix.png', width=600)

# %% [markdown]
# **Resim Üzerinden Test**

# %%
# !yolo task=detect mode=predict model=/content/ultralytics/runs/detect/train/weights/last.pt conf=0.60 source=/content/data_f1/images/val/

# %% [markdown]
# **Video Üzerinden Test**

# %%
# !yolo task=detect mode=predict model=/content/ultralytics/runs/detect/train/weights/last.pt conf=0.60 source=/content/drive/MyDrive/videoplayback_test.mp4
# Out:
# Ultralytics YOLOv8.0.5 🚀 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Fusing layers...
# Model summary: 268 layers, 68127420 parameters, 0 gradients, 257.4 GFLOPs
# video 1/1 (1/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 57.4ms
# video 1/1 (2/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 55.4ms
# video 1/1 (3/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 55.4ms
# video 1/1 (4/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 47.4ms
# video 1/1 (5/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 36.1ms
# video 1/1 (6/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 35.5ms
# video 1/1 (7/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 35.5ms
# video 1/1 (8/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 30.7ms
# video 1/1 (9/11204) /content/drive/MyDrive/videoplayback_test.mp4: 384x640 30.2ms
# ...
